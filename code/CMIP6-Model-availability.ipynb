# %% [markdown]
# # CMIP6 variable availability

# %% [markdown]
# This Notebook creates a colorcoded overview table to identify which models offer a given list of variables.
# The cells are colored with description as follows:
# - green (all): All variables are available for a specific model and scenario.
# - orange (list of variables): Less than what specified in ```limit``` number of variables are missing. The missing variables are noted inside the cell as a list.
# - red (missing): More then ```limit``` variables are missing.
# - black: No data available e.g. the scenario wasn't run for this model

# %%
# Imports
import intake
import pandas as pd
import seaborn as sns

# Load the catalog
col_url = "/work/ik1017/Catalogs/dkrz_cmip6_disk.json"
col = intake.open_esm_datastore(col_url)
# Out:
# /sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/intake_esm/cat.py:264: DtypeWarning: Columns (21,22,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
# Setup complete

# %%
# Define variables and scenarios to search for
variables = ["fgco2", "nbp", "npp", "gpp"] # ["fgco2", "nbp", "fLuc", "npp", "gpp", "rh", "ra", "cVeg", "cSoil", "cLitter"]
scenarios = ["historical", "ssp126", "ssp245", "ssp370", "ssp585"]

limit = 2 # number of variables alowed before labelled as missing

# %% [markdown]
# ## Functions

# %%
def search_catalog(variables: list, scenarios: list, limit=2):
    """
    Search the CMIP6 catalog for specific variables across different scenarios and models and generate an overview.

    Parameters:
        variables (list): List of CMIP6 variable IDs to search for in the catalog.
        scenarios (list): List of scenarios (e.g., 'historical', 'ssp245') to query.
        limit (int, optional): Threshold for how many missing variables are acceptable before labeling as "missing". Defaults to 2.

    Returns:
        pd.DataFrame: A DataFrame summarizing the availability of variables for each source model and scenario.
                      Values in the DataFrame are categorized as:
                      - "all": All variables are available.
                      - A list of missing variables if fewer than `limit` are missing.
                      - "missing": More than `limit` variables are missing.
                      - "none": No variables are available.
    """
    
    # Initialize a list to store DataFrames
    DF = []
    
    # Loop through each scenario and query the catalog
    for scenario in scenarios:
        activity = 'CMIP' if scenario == "historical" else 'ScenarioMIP'
        
        # Search the catalog and create an overview DataFrame
        query = dict(activity_id=activity, variable_id=variables, experiment_id=scenario)
        col_subset = col.search(**query)
        
        # Create a DataFrame overview of available data
        df_init = col_subset.df
        df_overview = df_init.groupby(['source_id', 'variable_id']).member_id.nunique().unstack()
        
        # List variables without data for each model
        df_overview[scenario] = df_overview.isna().apply(lambda row: row[row].index.tolist(), axis=1)
        
        # Append the DataFrame to the list
        DF.append(pd.DataFrame(df_overview[scenario]))
    
    # Merge all DataFrames from the different scenarios
    merged_df = DF[0]
    for df in DF[1:]:
        merged_df = merged_df.join(df, how='outer')
    
    # Fill NaN values with the number of variables
    merged_df = merged_df.fillna(len(variables))
    
    # Apply the mapping function to each column
    for column in merged_df.columns:
        merged_df[column] = merged_df[column].apply(map)

    return merged_df

# %%
def map(val):
    """
    Map the input value to a descriptive label based on its length or content.

    Parameters:
        val (list or other): The value to categorize.
    
    Returns:
        str: A descriptive label:
             - "all" if the list is empty.
             - A string representation of the list if its length is less than `limit`.
             - "missing" if its length exceeds `limit`.
             - "none" for any other unexpected cases.
    """
    
    try:
        if len(val) == 0:
            description = "all"
        elif len(val) < limit:
            description = str(val)
        else:
            description = "missing"           
    except:
        description = "none"

    return description

def highlight_color(val: str):
    """
    Apply a color-coding style based on the value.

    Parameters:
        val (str): The value to style, expected to be one of:
                   - "all"
                   - "none"
                   - "missing"
                   - A string representing a list of variables.
    
    Returns:
        str: CSS style for the background color:
             - Green for "all".
             - Black for "none".
             - Red for "missing".
             - Orange for other values.
    """
    
    if val == "all":
        return 'background-color: rgba(0,255,50)'
    elif val == "none":
        return 'background-color: rgba(0,0,0)'
    elif val == "missing":
        return 'background-color: rgba(255,0,0)'
    return 'background-color: rgba(255,165,0)'

# %%
def style_dataframe(df: pd.DataFrame):
    """
    Style a DataFrame for better visualization, including color-coded cells and column headers.

    Parameters:
        df (pd.DataFrame): The DataFrame to style.
    
    Returns:
        pd.io.formats.style.Styler: A styled version of the DataFrame with:
                                    - Color-coded cells based on their content.
                                    - Rotated column headers for compactness.
                                    - Grey dotted borders for all cells.
    """
    # Define styles for visualization
    table_styles = [
        dict(selector="th", props=[('width', '60px')]),
        dict(selector="th.col_heading", props=[('transform', 'rotateZ(-90deg)',), 
                                               ('max-height', '180px'), 
                                               ('height', '160px'), 
                                               ('max-width', '5px'), 
                                               ('vertical-align', 'left')])]
    
    # Apply styles and render the DataFrame
    styled_df = (
        df.style
        .applymap(highlight_color)
        .set_table_styles(table_styles)
        .set_properties(**{'border-color': 'grey', 'border-style': 'dotted', 'border-width': 'thin'}))
    
    return styled_df

# %% [markdown]
# ## Overview Table

# %%
df = search_catalog(variables, scenarios, limit=2)
style_dataframe(df)
# Out:
# <style type="text/css">
# #T_dd098 th {
#   width: 60px;
# }
# #T_dd098 th.col_heading {
#   transform: rotateZ(-90deg);
#   max-height: 180px;
#   height: 160px;
#   max-width: 5px;
#   vertical-align: left;
# }
# #T_dd098_row0_col0, #T_dd098_row0_col2, #T_dd098_row0_col3, #T_dd098_row5_col0, #T_dd098_row6_col0, #T_dd098_row7_col0, #T_dd098_row7_col2, #T_dd098_row7_col3, #T_dd098_row7_col4, #T_dd098_row8_col0, #T_dd098_row13_col0, #T_dd098_row13_col1, #T_dd098_row13_col2, #T_dd098_row13_col3, #T_dd098_row13_col4, #T_dd098_row14_col0, #T_dd098_row14_col1, #T_dd098_row14_col2, #T_dd098_row14_col3, #T_dd098_row14_col4, #T_dd098_row15_col0, #T_dd098_row15_col1, #T_dd098_row15_col2, #T_dd098_row15_col3, #T_dd098_row15_col4, #T_dd098_row23_col0, #T_dd098_row27_col0, #T_dd098_row27_col1, #T_dd098_row27_col2, #T_dd098_row27_col3, #T_dd098_row27_col4, #T_dd098_row28_col0, #T_dd098_row28_col1, #T_dd098_row28_col2, #T_dd098_row28_col3, #T_dd098_row28_col4, #T_dd098_row30_col0, #T_dd098_row30_col1, #T_dd098_row30_col2, #T_dd098_row30_col3, #T_dd098_row30_col4, #T_dd098_row32_col0, #T_dd098_row32_col1, #T_dd098_row32_col2, #T_dd098_row32_col3, #T_dd098_row32_col4, #T_dd098_row33_col0, #T_dd098_row33_col3, #T_dd098_row35_col0, #T_dd098_row35_col1, #T_dd098_row35_col2, #T_dd098_row35_col3, #T_dd098_row35_col4, #T_dd098_row36_col4, #T_dd098_row37_col0, #T_dd098_row38_col0, #T_dd098_row39_col0, #T_dd098_row39_col1, #T_dd098_row39_col2, #T_dd098_row39_col3, #T_dd098_row42_col0, #T_dd098_row42_col1, #T_dd098_row42_col2, #T_dd098_row42_col3, #T_dd098_row42_col4 {
#   background-color: rgba(0,255,50);
#   border-color: grey;
#   border-style: dotted;
#   border-width: thin;
# }
# #T_dd098_row0_col1, #T_dd098_row0_col4, #T_dd098_row1_col0, #T_dd098_row2_col0, #T_dd098_row2_col1, #T_dd098_row2_col2, #T_dd098_row2_col4, #T_dd098_row5_col1, #T_dd098_row5_col2, #T_dd098_row5_col3, #T_dd098_row5_col4, #T_dd098_row7_col1, #T_dd098_row9_col0, #T_dd098_row9_col1, #T_dd098_row9_col2, #T_dd098_row9_col3, #T_dd098_row9_col4, #T_dd098_row11_col0, #T_dd098_row11_col1, #T_dd098_row11_col2, #T_dd098_row11_col3, #T_dd098_row11_col4, #T_dd098_row12_col0, #T_dd098_row12_col1, #T_dd098_row12_col2, #T_dd098_row12_col3, #T_dd098_row16_col0, #T_dd098_row17_col0, #T_dd098_row19_col0, #T_dd098_row19_col1, #T_dd098_row19_col2, #T_dd098_row19_col3, #T_dd098_row19_col4, #T_dd098_row20_col0, #T_dd098_row21_col0, #T_dd098_row21_col2, #T_dd098_row21_col4, #T_dd098_row22_col1, #T_dd098_row22_col2, #T_dd098_row22_col3, #T_dd098_row22_col4, #T_dd098_row23_col1, #T_dd098_row23_col2, #T_dd098_row26_col0, #T_dd098_row29_col0, #T_dd098_row31_col0, #T_dd098_row38_col1, #T_dd098_row38_col3, #T_dd098_row38_col4, #T_dd098_row39_col4, #T_dd098_row41_col4 {
#   background-color: rgba(255,0,0);
#   border-color: grey;
#   border-style: dotted;
#   border-width: thin;
# }
# #T_dd098_row1_col1, #T_dd098_row1_col2, #T_dd098_row1_col3, #T_dd098_row1_col4, #T_dd098_row2_col3, #T_dd098_row4_col1, #T_dd098_row4_col2, #T_dd098_row4_col3, #T_dd098_row4_col4, #T_dd098_row6_col1, #T_dd098_row6_col2, #T_dd098_row6_col3, #T_dd098_row6_col4, #T_dd098_row8_col1, #T_dd098_row8_col2, #T_dd098_row8_col3, #T_dd098_row8_col4, #T_dd098_row10_col1, #T_dd098_row10_col2, #T_dd098_row10_col3, #T_dd098_row10_col4, #T_dd098_row12_col4, #T_dd098_row16_col1, #T_dd098_row16_col2, #T_dd098_row16_col3, #T_dd098_row16_col4, #T_dd098_row17_col1, #T_dd098_row17_col2, #T_dd098_row17_col3, #T_dd098_row17_col4, #T_dd098_row18_col1, #T_dd098_row18_col2, #T_dd098_row18_col3, #T_dd098_row18_col4, #T_dd098_row20_col1, #T_dd098_row20_col2, #T_dd098_row20_col3, #T_dd098_row20_col4, #T_dd098_row21_col1, #T_dd098_row21_col3, #T_dd098_row24_col1, #T_dd098_row24_col2, #T_dd098_row24_col3, #T_dd098_row24_col4, #T_dd098_row25_col1, #T_dd098_row25_col2, #T_dd098_row25_col3, #T_dd098_row25_col4, #T_dd098_row26_col1, #T_dd098_row26_col2, #T_dd098_row26_col3, #T_dd098_row26_col4, #T_dd098_row29_col1, #T_dd098_row29_col2, #T_dd098_row29_col3, #T_dd098_row29_col4, #T_dd098_row31_col1, #T_dd098_row31_col2, #T_dd098_row31_col3, #T_dd098_row31_col4, #T_dd098_row33_col1, #T_dd098_row33_col2, #T_dd098_row33_col4, #T_dd098_row36_col1, #T_dd098_row36_col2, #T_dd098_row36_col3, #T_dd098_row37_col1, #T_dd098_row37_col2, #T_dd098_row37_col3, #T_dd098_row37_col4, #T_dd098_row40_col1, #T_dd098_row40_col2, #T_dd098_row40_col3, #T_dd098_row40_col4, #T_dd098_row41_col1, #T_dd098_row41_col2 {
#   background-color: rgba(0,0,0);
#   border-color: grey;
#   border-style: dotted;
#   border-width: thin;
# }
# #T_dd098_row3_col0, #T_dd098_row3_col1, #T_dd098_row3_col2, #T_dd098_row3_col3, #T_dd098_row3_col4, #T_dd098_row4_col0, #T_dd098_row10_col0, #T_dd098_row18_col0, #T_dd098_row22_col0, #T_dd098_row23_col3, #T_dd098_row23_col4, #T_dd098_row24_col0, #T_dd098_row25_col0, #T_dd098_row34_col0, #T_dd098_row34_col1, #T_dd098_row34_col2, #T_dd098_row34_col3, #T_dd098_row34_col4, #T_dd098_row36_col0, #T_dd098_row38_col2, #T_dd098_row40_col0, #T_dd098_row41_col0, #T_dd098_row41_col3 {
#   background-color: rgba(255,165,0);
#   border-color: grey;
#   border-style: dotted;
#   border-width: thin;
# }
# </style>
# <table id="T_dd098">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd098_level0_col0" class="col_heading level0 col0" >historical</th>
#       <th id="T_dd098_level0_col1" class="col_heading level0 col1" >ssp126</th>
#       <th id="T_dd098_level0_col2" class="col_heading level0 col2" >ssp245</th>
#       <th id="T_dd098_level0_col3" class="col_heading level0 col3" >ssp370</th>
#       <th id="T_dd098_level0_col4" class="col_heading level0 col4" >ssp585</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >source_id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd098_level0_row0" class="row_heading level0 row0" >ACCESS-ESM1-5</th>
#       <td id="T_dd098_row0_col0" class="data row0 col0" >all</td>
#       <td id="T_dd098_row0_col1" class="data row0 col1" >missing</td>
#       <td id="T_dd098_row0_col2" class="data row0 col2" >all</td>
#       <td id="T_dd098_row0_col3" class="data row0 col3" >all</td>
#       <td id="T_dd098_row0_col4" class="data row0 col4" >missing</td>
#     </tr>
#     <tr>
#       <th id="T_dd098_level0_row1" class="row_heading level0 row1" >AWI-ESM-1-1-LR</th>
#       <td id="T_dd098_row1_col0" class="data row1 col0" >missing</td>
#       <td id="T_dd098_row1_col1" class="data row1 col1" >none</td>
#       <td id="T_dd098_row1_col2" class="data row1 col2" >none</td>
#       <td id="T_dd098_row1_col3" class="data row1 col3" >none</td>
#       <td id="T_dd098_row1_col4" class="data row1 col4" >none</td>
#     </tr>
#     <tr>
#       <th id="T_dd098_level0_row2" class="row_heading level0 row2" >AWI-ESM-1-REcoM</th>
#       <td id="T_dd098_row2_col0" class="data row2 col0" >missing</td>
#       <td id="T_dd098_row2_col1" class="data row2 col1" >missing</td>
#       <td id="T_dd098_row2_col2" class="data row2 col2" >missing</td>
#       <td id="T_dd098_row2_col3" class="data row2 col3" >none</td>
#       <td id="T_dd098_row2_col4" class="data row2 col4" >missing</td>
#     </tr>
#     <tr>
#       <th id="T_dd098_level0_row3" class="row_heading level0 row3" >BCC-CSM2-MR</th>
#       <td id="T_dd098_row3_col0" class="data row3 col0" >['nbp']</td>
#       <td id="T_dd098_row3_col1" class="data row3 col1" >['nbp']</td>
#       <td id="T_dd098_row3_col2" class="data row3 col2" >['nbp']</td>
#       <td id="T_dd098_row3_col3" class="data row3 col3" >['nbp']</td>
#       <td id="T_dd098_row3_col4" class="data row3 col4" >['nbp']</td>
#     </tr>
#     <tr>
#       <th id="T_dd098_level0_row4" class="row_heading level0 row4" >BCC-ESM1</th>
#       <td id="T_dd098_row4_col0" class="data row4 col0" >['nbp']</td>
#       <td id="T_dd098_row4_col1" class="data row4 col1" >none</td>
#       <td id="T_dd098_row4_col2" class="data row4 col2" >none</td>
#       <td id="T
