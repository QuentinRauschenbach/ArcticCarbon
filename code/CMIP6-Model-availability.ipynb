# %%
# Imports
import os
import sys
import glob
import pickle
import re
import subprocess
import intake
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from cdo import Cdo

# Initialize CDO for climate data operations
cdo = Cdo()

# Confirm setup
print("Setup complete")
# Out:
# Setup complete

# %%
# Load the catalog
col_url = "/work/ik1017/Catalogs/dkrz_cmip6_disk.json"
col = intake.open_esm_datastore(col_url)
# Out:
# /sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/intake_esm/cat.py:264: DtypeWarning: Columns (21,22,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(

# %%
# Define variables and scenarios
#variables = ["fgco2", "nbp", "fLuc", "npp", "gpp", "rh", "ra", "cVeg", "cSoil", "cLitter"]
variables = ["fgco2", "nbp", "npp", "gpp"]

#variables = ["fgco2", "intpp", "intpoc", "intdic", "intdoc", "cSoil", "cVeg", "fLuc", "gpp", "nbp", "nep", "npp", "ra", "rh"]
scenarios = ["historical", "ssp126", "ssp245", "ssp370", "ssp585"]
limit = 5 # number of variables alowd to be missing

# %%
# Initialize a list to store DataFrames
DF = []

# Loop through each scenario and query the catalog
for scenario in scenarios:
    activity = 'CMIP' if scenario == "historical" else 'ScenarioMIP'
    
    # Search the catalog and create an overview DataFrame
    query = dict(activity_id=activity, variable_id=variables, experiment_id=scenario)
    col_subset = col.search(**query)
    
    # Create a DataFrame overview of available data
    df_init = col_subset.df
    df_overview = df_init.groupby(['source_id', 'variable_id']).member_id.nunique().unstack()
    
    # List variables without data for each model
    df_overview[scenario] = df_overview.isna().apply(lambda row: row[row].index.tolist(), axis=1)
    
    # Append the DataFrame to the list
    DF.append(pd.DataFrame(df_overview[scenario]))

# Merge all DataFrames
merged_df = DF[0]
for df in DF[1:]:
    merged_df = merged_df.join(df, how='outer')

# Fill NaN values with the number of variables
merged_df = merged_df.fillna(len(variables))

# %%
def map(val):
    try:
        if len(val) == 0:
            description = "all"
        elif len(val) < limit:
            description = str(val)
        else:
            description = "missing"           
    except:
        description = "none"

    return description

# %%
# Apply the mapping function to each column
for column in merged_df.columns:
    merged_df[column] = merged_df[column].apply(map)

# %%
# Styling the DataFrame for visualization
table_styles = [
    dict(selector="th", props=[('width', '60px')]),
    dict(selector="th.col_heading", props=[('transform', 'rotateZ(-90deg)',), 
                                           ('max-height', '180px'), 
                                           ('height', '160px'), 
                                           ('max-width', '5px'), 
                                           ('vertical-align', 'left')])
]

# Function to apply color highlighting based on value
def highlight_color(val):
    if val == "all":
        return 'background-color: rgba(0,255,50)'
    elif val == "none":
        return 'background-color: rgba(0,0,0)'
    elif val == "missing":
        return 'background-color: rgba(255,0,0)'
    return 'background-color: rgba(255,165,0)'

# Apply styles and render the DataFrame
styled_df = (
    merged_df.style
    .applymap(highlight_color)
    .set_table_styles(table_styles)
    .set_properties(**{'border-color': 'grey', 'border-style': 'dotted', 'border-width': 'thin'})
)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_5f407 th {
#   width: 60px;
# }
# #T_5f407 th.col_heading {
#   transform: rotateZ(-90deg);
#   max-height: 180px;
#   height: 160px;
#   max-width: 5px;
#   vertical-align: left;
# }
# #T_5f407_row0_col0, #T_5f407_row0_col2, #T_5f407_row0_col3, #T_5f407_row5_col0, #T_5f407_row6_col0, #T_5f407_row7_col0, #T_5f407_row7_col2, #T_5f407_row7_col3, #T_5f407_row7_col4, #T_5f407_row8_col0, #T_5f407_row13_col0, #T_5f407_row13_col1, #T_5f407_row13_col2, #T_5f407_row13_col3, #T_5f407_row13_col4, #T_5f407_row14_col0, #T_5f407_row14_col1, #T_5f407_row14_col2, #T_5f407_row14_col3, #T_5f407_row14_col4, #T_5f407_row15_col0, #T_5f407_row15_col1, #T_5f407_row15_col2, #T_5f407_row15_col3, #T_5f407_row15_col4, #T_5f407_row23_col0, #T_5f407_row27_col0, #T_5f407_row27_col1, #T_5f407_row27_col2, #T_5f407_row27_col3, #T_5f407_row27_col4, #T_5f407_row28_col0, #T_5f407_row28_col1, #T_5f407_row28_col2, #T_5f407_row28_col3, #T_5f407_row28_col4, #T_5f407_row30_col0, #T_5f407_row30_col1, #T_5f407_row30_col2, #T_5f407_row30_col3, #T_5f407_row30_col4, #T_5f407_row32_col0, #T_5f407_row32_col1, #T_5f407_row32_col2, #T_5f407_row32_col3, #T_5f407_row32_col4, #T_5f407_row33_col0, #T_5f407_row33_col3, #T_5f407_row35_col0, #T_5f407_row35_col1, #T_5f407_row35_col2, #T_5f407_row35_col3, #T_5f407_row35_col4, #T_5f407_row36_col4, #T_5f407_row37_col0, #T_5f407_row38_col0, #T_5f407_row39_col0, #T_5f407_row39_col1, #T_5f407_row39_col2, #T_5f407_row39_col3, #T_5f407_row42_col0, #T_5f407_row42_col1, #T_5f407_row42_col2, #T_5f407_row42_col3, #T_5f407_row42_col4 {
#   background-color: rgba(0,255,50);
#   border-color: grey;
#   border-style: dotted;
#   border-width: thin;
# }
# #T_5f407_row0_col1, #T_5f407_row0_col4, #T_5f407_row1_col0, #T_5f407_row2_col0, #T_5f407_row2_col1, #T_5f407_row2_col2, #T_5f407_row2_col4, #T_5f407_row3_col0, #T_5f407_row3_col1, #T_5f407_row3_col2, #T_5f407_row3_col3, #T_5f407_row3_col4, #T_5f407_row4_col0, #T_5f407_row5_col1, #T_5f407_row5_col2, #T_5f407_row5_col3, #T_5f407_row5_col4, #T_5f407_row7_col1, #T_5f407_row9_col0, #T_5f407_row9_col1, #T_5f407_row9_col2, #T_5f407_row9_col3, #T_5f407_row9_col4, #T_5f407_row10_col0, #T_5f407_row11_col0, #T_5f407_row11_col1, #T_5f407_row11_col2, #T_5f407_row11_col3, #T_5f407_row11_col4, #T_5f407_row12_col0, #T_5f407_row12_col1, #T_5f407_row12_col2, #T_5f407_row12_col3, #T_5f407_row16_col0, #T_5f407_row17_col0, #T_5f407_row18_col0, #T_5f407_row19_col0, #T_5f407_row19_col1, #T_5f407_row19_col2, #T_5f407_row19_col3, #T_5f407_row19_col4, #T_5f407_row20_col0, #T_5f407_row21_col0, #T_5f407_row21_col2, #T_5f407_row21_col4, #T_5f407_row22_col0, #T_5f407_row22_col1, #T_5f407_row22_col2, #T_5f407_row22_col3, #T_5f407_row22_col4, #T_5f407_row23_col1, #T_5f407_row23_col2, #T_5f407_row23_col3, #T_5f407_row23_col4, #T_5f407_row24_col0, #T_5f407_row25_col0, #T_5f407_row26_col0, #T_5f407_row29_col0, #T_5f407_row31_col0, #T_5f407_row34_col0, #T_5f407_row34_col1, #T_5f407_row34_col2, #T_5f407_row34_col3, #T_5f407_row34_col4, #T_5f407_row36_col0, #T_5f407_row38_col1, #T_5f407_row38_col2, #T_5f407_row38_col3, #T_5f407_row38_col4, #T_5f407_row39_col4, #T_5f407_row40_col0, #T_5f407_row41_col0, #T_5f407_row41_col3, #T_5f407_row41_col4 {
#   background-color: rgba(255,165,0);
#   border-color: grey;
#   border-style: dotted;
#   border-width: thin;
# }
# #T_5f407_row1_col1, #T_5f407_row1_col2, #T_5f407_row1_col3, #T_5f407_row1_col4, #T_5f407_row2_col3, #T_5f407_row4_col1, #T_5f407_row4_col2, #T_5f407_row4_col3, #T_5f407_row4_col4, #T_5f407_row6_col1, #T_5f407_row6_col2, #T_5f407_row6_col3, #T_5f407_row6_col4, #T_5f407_row8_col1, #T_5f407_row8_col2, #T_5f407_row8_col3, #T_5f407_row8_col4, #T_5f407_row10_col1, #T_5f407_row10_col2, #T_5f407_row10_col3, #T_5f407_row10_col4, #T_5f407_row12_col4, #T_5f407_row16_col1, #T_5f407_row16_col2, #T_5f407_row16_col3, #T_5f407_row16_col4, #T_5f407_row17_col1, #T_5f407_row17_col2, #T_5f407_row17_col3, #T_5f407_row17_col4, #T_5f407_row18_col1, #T_5f407_row18_col2, #T_5f407_row18_col3, #T_5f407_row18_col4, #T_5f407_row20_col1, #T_5f407_row20_col2, #T_5f407_row20_col3, #T_5f407_row20_col4, #T_5f407_row21_col1, #T_5f407_row21_col3, #T_5f407_row24_col1, #T_5f407_row24_col2, #T_5f407_row24_col3, #T_5f407_row24_col4, #T_5f407_row25_col1, #T_5f407_row25_col2, #T_5f407_row25_col3, #T_5f407_row25_col4, #T_5f407_row26_col1, #T_5f407_row26_col2, #T_5f407_row26_col3, #T_5f407_row26_col4, #T_5f407_row29_col1, #T_5f407_row29_col2, #T_5f407_row29_col3, #T_5f407_row29_col4, #T_5f407_row31_col1, #T_5f407_row31_col2, #T_5f407_row31_col3, #T_5f407_row31_col4, #T_5f407_row33_col1, #T_5f407_row33_col2, #T_5f407_row33_col4, #T_5f407_row36_col1, #T_5f407_row36_col2, #T_5f407_row36_col3, #T_5f407_row37_col1, #T_5f407_row37_col2, #T_5f407_row37_col3, #T_5f407_row37_col4, #T_5f407_row40_col1, #T_5f407_row40_col2, #T_5f407_row40_col3, #T_5f407_row40_col4, #T_5f407_row41_col1, #T_5f407_row41_col2 {
#   background-color: rgba(0,0,0);
#   border-color: grey;
#   border-style: dotted;
#   border-width: thin;
# }
# </style>
# <table id="T_5f407">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f407_level0_col0" class="col_heading level0 col0" >historical</th>
#       <th id="T_5f407_level0_col1" class="col_heading level0 col1" >ssp126</th>
#       <th id="T_5f407_level0_col2" class="col_heading level0 col2" >ssp245</th>
#       <th id="T_5f407_level0_col3" class="col_heading level0 col3" >ssp370</th>
#       <th id="T_5f407_level0_col4" class="col_heading level0 col4" >ssp585</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >source_id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f407_level0_row0" class="row_heading level0 row0" >ACCESS-ESM1-5</th>
#       <td id="T_5f407_row0_col0" class="data row0 col0" >all</td>
#       <td id="T_5f407_row0_col1" class="data row0 col1" >['gpp', 'nbp', 'npp']</td>
#       <td id="T_5f407_row0_col2" class="data row0 col2" >all</td>
#       <td id="T_5f407_row0_col3" class="data row0 col3" >all</td>
#       <td id="T_5f407_row0_col4" class="data row0 col4" >['gpp', 'nbp', 'npp']</td>
#     </tr>
#     <tr>
#       <th id="T_5f407_level0_row1" class="row_heading level0 row1" >AWI-ESM-1-1-LR</th>
#       <td id="T_5f407_row1_col0" class="data row1 col0" >['fgco2', 'nbp']</td>
#       <td id="T_5f407_row1_col1" class="data row1 col1" >none</td>
#       <td id="T_5f407_row1_col2" class="data row1 col2" >none</td>
#       <td id="T_5f407_row1_col3" class="data row1 col3" >none</td>
#       <td id="T_5f407_row1_col4" class="data row1 col4" >none</td>
#     </tr>
#     <tr>
#       <th id="T_5f407_level0_row2" class="row_heading level0 row2" >AWI-ESM-1-REcoM</th>
#       <td id="T_5f407_row2_col0" class="data row2 col0" >['fgco2', 'nbp']</td>
#       <td id="T_5f407_row2_col1" class="data row2 col1" >['fgco2', 'nbp']</td>
#       <td id="T_5f407_row2_col2" class="data row2 col2" >['fgco2', 'nbp']</td>
#       <td id="T_5f407_row2_col3" class="data row2 col3" >none</td>
#       <td id="T_5f407_row2_col4" class="data row2 col4" >['fgco2', 'nbp']</td>
#     </tr>
#     <tr>
#       <th id="T_5f407_level0_row3" class="row_heading level0 row3" >BCC-CSM2-MR</th>
#       <td id="T_5f407_row3_col0" class="data row3 col0" >['nbp']</td>
#       <td id="T_5f407_row3_col1" class="data row3 col1" >['nbp']</td>
#       <td id="T_5f407_row3_col2" class="data row3 col2" >['nbp']</td>
#       <td id="T_5f407_row3_col3" class="data row3 col3" >['nbp']</td>
#       <td id="T_5f407_row3_col4" class="data row3 col4" >['nbp']</td>
#     </tr>
#     <tr>
#       <th id="T_5f407_level0_row4" class="row_heading level0 row4" >BCC-ESM1</th>
#       <td id="T_5f407_row4_col0" class="data row4 col0" >['nbp']</td>
#       <td id="T_5f407_row4_col1" class="data row4 col1" >none</td>
#       <td id="T_5f407_row4_col2" class="data row4 col2" >none</td>
#       <td id="T_5f407_row4_col3" class="data row

# %%
# Styling the DataFrame for visualization
table_styles = [
    dict(selector="th", props=[('width', '60px')]),
    dict(selector="th.col_heading", props=[('transform', 'rotateZ(-90deg)',), 
                                           ('max-height', '180px'), 
                                           ('height', '160px'), 
                                           ('max-width', '5px'), 
                                           ('vertical-align', 'left')])
]

# Function to apply color highlighting based on value
def highlight_color(val):
    if val == "all":
        return 'background-color: rgba(0,255,50)'
    elif val == "none":
        return 'background-color: rgba(0,0,0)'
    elif val == "missing":
        return 'background-color: rgba(255,0,0)'
    return 'background-color: rgba(255,165,0)'

# Apply styles and render the DataFrame
styled_df = (
    merged_df.style
    .applymap(highlight_color)
    .set_table_styles(table_styles)
    .set_properties(**{'border-color': 'grey', 'border-style': 'dotted', 'border-width': 'thin'})
)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_aee02 th {
#   width: 60px;
# }
# #T_aee02 th.col_heading {
#   transform: rotateZ(-90deg);
#   max-height: 180px;
#   height: 160px;
#   max-width: 5px;
#   vertical-align: left;
# }
# #T_aee02_row0_col0, #T_aee02_row0_col2, #T_aee02_row0_col3, #T_aee02_row1_col0, #T_aee02_row2_col0, #T_aee02_row2_col1, #T_aee02_row2_col2, #T_aee02_row2_col4, #T_aee02_row3_col0, #T_aee02_row3_col1, #T_aee02_row3_col2, #T_aee02_row3_col3, #T_aee02_row3_col4, #T_aee02_row4_col0, #T_aee02_row9_col2, #T_aee02_row14_col0, #T_aee02_row14_col1, #T_aee02_row14_col2, #T_aee02_row14_col3, #T_aee02_row14_col4, #T_aee02_row15_col0, #T_aee02_row15_col1, #T_aee02_row15_col2, #T_aee02_row15_col3, #T_aee02_row15_col4, #T_aee02_row22_col0, #T_aee02_row23_col0, #T_aee02_row27_col0, #T_aee02_row27_col1, #T_aee02_row27_col2, #T_aee02_row27_col3, #T_aee02_row27_col4, #T_aee02_row28_col0, #T_aee02_row28_col1, #T_aee02_row28_col2, #T_aee02_row28_col3, #T_aee02_row28_col4, #T_aee02_row32_col0, #T_aee02_row32_col1, #T_aee02_row32_col2, #T_aee02_row32_col3, #T_aee02_row32_col4, #T_aee02_row36_col0, #T_aee02_row38_col0, #T_aee02_row40_col0, #T_aee02_row41_col0, #T_aee02_row41_col3, #T_aee02_row42_col0, #T_aee02_row42_col1, #T_aee02_row42_col2, #T_aee02_row42_col3, #T_aee02_row42_col4 {
#   background-color: rgba(255,165,0);
#   border-color: grey;
#   border-style: dotted;
#   border-width: thin;
# }
# #T_aee02_row0_col1, #T_aee02_row0_col4, #T_aee02_row5_col1, #T_aee02_row5_col2, #T_aee02_row5_col3, #T_aee02_row5_col4, #T_aee02_row7_col1, #T_aee02_row9_col0, #T_aee02_row9_col1, #T_aee02_row9_col3, #T_aee02_row9_col4, #T_aee02_row10_col0, #T_aee02_row11_col0, #T_aee02_row11_col1, #T_aee02_row11_col2, #T_aee02_row11_col3, #T_aee02_row11_col4, #T_aee02_row12_col0, #T_aee02_row12_col1, #T_aee02_row12_col2, #T_aee02_row12_col3, #T_aee02_row16_col0, #T_aee02_row17_col0, #T_aee02_row18_col0, #T_aee02_row19_col0, #T_aee02_row19_col1, #T_aee02_row19_col2, #T_aee02_row19_col3, #T_aee02_row19_col4, #T_aee02_row20_col0, #T_aee02_row21_col0, #T_aee02_row21_col2, #T_aee02_row21_col4, #T_aee02_row22_col1, #T_aee02_row22_col2, #T_aee02_row22_col3, #T_aee02_row22_col4, #T_aee02_row23_col1, #T_aee02_row23_col2, #T_aee02_row23_col3, #T_aee02_row23_col4, #T_aee02_row24_col0, #T_aee02_row25_col0, #T_aee02_row26_col0, #T_aee02_row29_col0, #T_aee02_row31_col0, #T_aee02_row34_col0, #T_aee02_row34_col1, #T_aee02_row34_col2, #T_aee02_row34_col3, #T_aee02_row34_col4, #T_aee02_row38_col1, #T_aee02_row38_col2, #T_aee02_row38_col3, #T_aee02_row38_col4, #T_aee02_row39_col4, #T_aee02_row41_col4 {
#   background-color: rgba(255,0,0);
#   border-color: grey;
#   border-style: dotted;
#   border-width: thin;
# }
# #T_aee02_row1_col1, #T_aee02_row1_col2, #T_aee02_row1_col3, #T_aee02_row1_col4, #T_aee02_row2_col3, #T_aee02_row4_col1, #T_aee02_row4_col2, #T_aee02_row4_col3, #T_aee02_row4_col4, #T_aee02_row6_col1, #T_aee02_row6_col2, #T_aee02_row6_col3, #T_aee02_row6_col4, #T_aee02_row8_col1, #T_aee02_row8_col2, #T_aee02_row8_col3, #T_aee02_row8_col4, #T_aee02_row10_col1, #T_aee02_row10_col2, #T_aee02_row10_col3, #T_aee02_row10_col4, #T_aee02_row12_col4, #T_aee02_row16_col1, #T_aee02_row16_col2, #T_aee02_row16_col3, #T_aee02_row16_col4, #T_aee02_row17_col1, #T_aee02_row17_col2, #T_aee02_row17_col3, #T_aee02_row17_col4, #T_aee02_row18_col1, #T_aee02_row18_col2, #T_aee02_row18_col3, #T_aee02_row18_col4, #T_aee02_row20_col1, #T_aee02_row20_col2, #T_aee02_row20_col3, #T_aee02_row20_col4, #T_aee02_row21_col1, #T_aee02_row21_col3, #T_aee02_row24_col1, #T_aee02_row24_col2, #T_aee02_row24_col3, #T_aee02_row24_col4, #T_aee02_row25_col1, #T_aee02_row25_col2, #T_aee02_row25_col3, #T_aee02_row25_col4, #T_aee02_row26_col1, #T_aee02_row26_col2, #T_aee02_row26_col3, #T_aee02_row26_col4, #T_aee02_row29_col1, #T_aee02_row29_col2, #T_aee02_row29_col3, #T_aee02_row29_col4, #T_aee02_row31_col1, #T_aee02_row31_col2, #T_aee02_row31_col3, #T_aee02_row31_col4, #T_aee02_row33_col1, #T_aee02_row33_col2, #T_aee02_row33_col4, #T_aee02_row36_col1, #T_aee02_row36_col2, #T_aee02_row36_col3, #T_aee02_row37_col1, #T_aee02_row37_col2, #T_aee02_row37_col3, #T_aee02_row37_col4, #T_aee02_row40_col1, #T_aee02_row40_col2, #T_aee02_row40_col3, #T_aee02_row40_col4, #T_aee02_row41_col1, #T_aee02_row41_col2 {
#   background-color: rgba(0,0,0);
#   border-color: grey;
#   border-style: dotted;
#   border-width: thin;
# }
# #T_aee02_row5_col0, #T_aee02_row6_col0, #T_aee02_row7_col0, #T_aee02_row7_col2, #T_aee02_row7_col3, #T_aee02_row7_col4, #T_aee02_row8_col0, #T_aee02_row13_col0, #T_aee02_row13_col1, #T_aee02_row13_col2, #T_aee02_row13_col3, #T_aee02_row13_col4, #T_aee02_row30_col0, #T_aee02_row30_col1, #T_aee02_row30_col2, #T_aee02_row30_col3, #T_aee02_row30_col4, #T_aee02_row33_col0, #T_aee02_row33_col3, #T_aee02_row35_col0, #T_aee02_row35_col1, #T_aee02_row35_col2, #T_aee02_row35_col3, #T_aee02_row35_col4, #T_aee02_row36_col4, #T_aee02_row37_col0, #T_aee02_row39_col0, #T_aee02_row39_col1, #T_aee02_row39_col2, #T_aee02_row39_col3 {
#   background-color: rgba(0,255,50);
#   border-color: grey;
#   border-style: dotted;
#   border-width: thin;
# }
# </style>
# <table id="T_aee02">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aee02_level0_col0" class="col_heading level0 col0" >historical</th>
#       <th id="T_aee02_level0_col1" class="col_heading level0 col1" >ssp126</th>
#       <th id="T_aee02_level0_col2" class="col_heading level0 col2" >ssp245</th>
#       <th id="T_aee02_level0_col3" class="col_heading level0 col3" >ssp370</th>
#       <th id="T_aee02_level0_col4" class="col_heading level0 col4" >ssp585</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >source_id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aee02_level0_row0" class="row_heading level0 row0" >ACCESS-ESM1-5</th>
#       <td id="T_aee02_row0_col0" class="data row0 col0" >['fLuc']</td>
#       <td id="T_aee02_row0_col1" class="data row0 col1" >missing</td>
#       <td id="T_aee02_row0_col2" class="data row0 col2" >['fLuc']</td>
#       <td id="T_aee02_row0_col3" class="data row0 col3" >['fLuc']</td>
#       <td id="T_aee02_row0_col4" class="data row0 col4" >missing</td>
#     </tr>
#     <tr>
#       <th id="T_aee02_level0_row1" class="row_heading level0 row1" >AWI-ESM-1-1-LR</th>
#       <td id="T_aee02_row1_col0" class="data row1 col0" >['fgco2', 'nbp', 'rh']</td>
#       <td id="T_aee02_row1_col1" class="data row1 col1" >none</td>
#       <td id="T_aee02_row1_col2" class="data row1 col2" >none</td>
#       <td id="T_aee02_row1_col3" class="data row1 col3" >none</td>
#       <td id="T_aee02_row1_col4" class="data row1 col4" >none</td>
#     </tr>
#     <tr>
#       <th id="T_aee02_level0_row2" class="row_heading level0 row2" >AWI-ESM-1-REcoM</th>
#       <td id="T_aee02_row2_col0" class="data row2 col0" >['fgco2', 'nbp', 'rh']</td>
#       <td id="T_aee02_row2_col1" class="data row2 col1" >['fgco2', 'nbp', 'rh']</td>
#       <td id="T_aee02_row2_col2" class="data row2 col2" >['fgco2', 'nbp', 'rh']</td>
#       <td id="T_aee02_row2_col3" class="data row2 col3" >none</td>
#       <td id="T_aee02_row2_col4" class="data row2 col4" >['fgco2', 'nbp', 'rh']</td>
#     </tr>
#     <tr>
#       <th id="T_aee02_level0_row3" class="row_heading level0 row3" >BCC-CSM2-MR</th>
#       <td id="T_aee02_row3_col0" class="data row3 col0" >['fLuc', 'nbp']</td>
#       <td id="T_aee02_row3_col1" class="data row3 col1" >['fLuc', 'nbp']</td>
#       <td id="T_aee02_row3_col2" class="data row3 col2" >['fLuc', 'nbp']</td>
#       <td id="T_aee02_row3_col3" class="data row3 col3" >['fLuc', 'nbp']</td>
#       <td id="T_aee02_row3_col4" class="data row3 col4" >['fLuc', 'nbp']</td>
#     </tr>
#     <tr>
#       <th id="T_aee02_level0_row4" class="row_heading level0 row4" >BCC-ESM1</th>
#       <td id="T_aee02_row4_col0" class="data row4 col0" >['fLuc', 'nbp']</td>
#       <td i
